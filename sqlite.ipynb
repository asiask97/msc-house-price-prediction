# %% [markdown]
# This file is used to read the db to see the results saved

# %%
import sqlite3, pandas as pd
con = sqlite3.connect("Outputs/experiments.db")

# %%
pd.read_sql_query(
    "SELECT * "
    "FROM runs", con)

# %%
#pd.set_option("display.max_colwidth", None)   # stop truncating cell contents
#pd.set_option("display.max_columns", None)    # show all columns too

pd.read_sql_query(
    "SELECT * "
    "FROM results", con)

# %%
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)
storage = "sqlite:///Outputs/optuna_study.db"

# %%
[s.study_name for s in optuna.get_all_study_summaries(storage)]

# %%
study = optuna.load_study(study_name="RandomForest_bde28ff733f7", storage=storage)
study.trials_dataframe()   # number, value (CV MAPE), state, and every param column

# %%
import sqlite3, pandas as pd
con_2 = sqlite3.connect("Outputs/interval_experiments.db")


pd.read_sql_query(
    "SELECT * "
    "FROM results", con_2)
# Out:
#          run_id     model  confidence  coverage  mean_width_gbp  \
# 0  acc3bd642689   XGBoost         0.9  0.900615   192701.603223
# 1  acc3bd642689  LightGBM         0.9  0.900370   188192.462581
# 2  91748411c146   XGBoost         0.9  0.900865   197021.633359
# 3  91748411c146  LightGBM         0.9  0.900245   190187.649312
#
#    median_width_gbp  conformal_offset_log  \
# 0     144831.542371              0.029967
# 1     138349.906669              0.033089
# 2     146702.566521              0.025818
# 3     139804.147744              0.026464
#
#                                         lower_params  \
# 0  {"learning_rate": 0.01520624543352963, "max_de...
# 1  {"learning_rate": 0.06404378316033957, "max_de...
# 2  {"learning_rate": 0.06577003111971265, "max_de...
# 3  {"learning_rate": 0.03158180542871436, "max_de...
#
#                                         upper_params  lower_pinball  \
# 0  {"learning_rate": 0.047736451424987114, "max_d...       0.024947
# 1  {"learning_rate": 0.0767483601248314, "max_dep...       0.024468
# 2  {"learning_rate": 0.021341773912339133, "max_d...       0.024644
# 3  {"learning_rate": 0.08760515613848693, "max_de...       0.024504
#
#    upper_pinball warm_start_run  tune_seconds            timestamp  \
# 0       0.019667   bde28ff733f7       11757.7  2026-08-16T00:13:43
# 1       0.018995   0c93d2c5a43c        2755.4  2026-08-16T01:00:12
# 2       0.020026   bde28ff733f7       10816.0  2026-08-16T04:10:05
# 3       0.018926   0c93d2c5a43c        2614.1  2026-08-16T04:54:02
#
#    mean_rel_width_pct  median_rel_width_pct
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2           67.638170             59.344915
# 3           64.136968             57.121680
